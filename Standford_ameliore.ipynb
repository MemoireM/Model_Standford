# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (4.66.4)

# %%
import nltk
from nltk.tag import StanfordNERTagger

# Stanford NER 模型路径
#stanford_classifier = "stanford-ner-4.2.0/classifiers/english.all.3class.distsim.crf.ser.gz"
stanford_classifier = "/Users/zhengruixing/Desktop/stanford-ner-2020-11-17/classifiers/english.all.3class.distsim.crf.ser.gz"
stanford_ner_path ="/Users/zhengruixing/Desktop/stanford-ner-2020-11-17/stanford-ner.jar"


# 创建 NER 标注器
ner_tagger = StanfordNERTagger(stanford_classifier, stanford_ner_path, encoding='utf-8')

# 示例文本
text = "Barack Obama was born in Hawaii. He was the 44th President of the United States."

# 分词
words = nltk.word_tokenize(text)

# 进行 NER 标注
ner_results = ner_tagger.tag(words)

# 打印结果
print(ner_results)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-1-949e60e159ac> in <cell line: 0>()
#       9
#      10 # 创建 NER 标注器
# ---> 11 ner_tagger = StanfordNERTagger(stanford_classifier, stanford_ner_path, encoding='utf-8')
#      12
#      13 # 示例文本
#
# /usr/local/lib/python3.11/dist-packages/nltk/tag/stanford.py in __init__(self, *args, **kwargs)
#     198
#     199     def __init__(self, *args, **kwargs):
# --> 200         super().__init__(*args, **kwargs)
#     201
#     202     @property
#
# /usr/local/lib/python3.11/dist-packages/nltk/tag/stanford.py in __init__(self, model_filename, path_to_jar, encoding, verbose, java_options)
#      68                 "StanfordPOSTagger or StanfordNERTagger?"
#      69             )
# ---> 70         self._stanford_jar = find_jar(
#      71             self._JAR, path_to_jar, searchpath=(), url=_stanford_url, verbose=verbose
#      72         )
#
# /usr/local/lib/python3.11/dist-packages/nltk/internals.py in find_jar(name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex)
#     833     is_regex=False,
#     834 ):
# --> 835     return next(
#     836         find_jar_iter(
#     837             name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex
#
# /usr/local/lib/python3.11/dist-packages/nltk/internals.py in find_jar_iter(name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex)
#     719             yield path_to_jar
#     720         else:
# --> 721             raise LookupError(
#     722                 f"Could not find {name_pattern} jar file at {path_to_jar}"
#     723             )
#
# LookupError: Could not find stanford-ner.jar jar file at /Users/zhengruixing/Desktop/stanford-ner-2020-11-17/stanford-ner.jar

# %%
import nltk
from nltk.tag import StanfordNERTagger
import re


stanford_classifier = "/Users/zhengruixing/Desktop/stanford-ner-2020-11-17/classifiers/english.all.3class.distsim.crf.ser.gz"
stanford_ner_path = "/Users/zhengruixing/Desktop/stanford-ner-2020-11-17/stanford-ner.jar"


ner_tagger = StanfordNERTagger(stanford_classifier, stanford_ner_path, encoding='utf-8')

with open("/Users/zhengruixing/Desktop/Corpus/APPOLINAIRE_Caligrammes.txt", "r", encoding="utf-8") as f:
    texte = f.read().strip()

words = nltk.word_tokenize(texte)


ner_results = ner_tagger.tag(words)

liste_entitesnom = []
liste_mots = []

for word, tag in ner_results:
    if tag != "O":
        liste_entitesnom.append({"mot": word, "type": tag})
    else:
        liste_mots.append(word)


print(f"Entités   : {len(liste_entitesnom)}")
print(f"Candidats : {len(liste_mots)}")
print(liste_entitesnom[:20])
print("-"*20)
print(list(liste_mots)[:20])
# Out:
# Entités   : 329
# Candidats : 15393
# [{'mot': 'Texte', 'type': 'ORGANIZATION'}, {'mot': 'Vues', 'type': 'ORGANIZATION'}, {'mot': 'Calligrammes', 'type': 'ORGANIZATION'}, {'mot': '', 'type': 'ORGANIZATION'}, {'mot': 'Guillaume', 'type': 'ORGANIZATION'}, {'mot': 'Apollinaire', 'type': 'ORGANIZATION'}, {'mot': 'Guillaume', 'type': 'PERSON'}, {'mot': 'Lausanne', 'type': 'LOCATION'}, {'mot': 'Roger', 'type': 'PERSON'}, {'mot': 'France', 'type': 'LOCATION'}, {'mot': 'Il', 'type': 'PERSON'}, {'mot': 'GUILLAUME', 'type': 'PERSON'}, {'mot': 'APOLLINAIRE', 'type': 'PERSON'}, {'mot': 'Cordes', 'type': 'PERSON'}, {'mot': 'Cordes', 'type': 'PERSON'}, {'mot': 'Cordes', 'type': 'PERSON'}, {'mot': 'Cordes', 'type': 'PERSON'}, {'mot': 'Bigorneaux', 'type': 'LOCATION'}, {'mot': 'Lotte', 'type': 'LOCATION'}, {'mot': 'Puits', 'type': 'PERSON'}]
# --------------------
# ['Rappel', 'de', 'votre', 'demande', ':', 'Format', 'de', 'téléchargement', ':', ':', '1', 'à', '262', 'sur', '262', 'Nombre', 'de', 'pages', ':', '262']

# %%
import nltk
from nltk.tag import StanfordNERTagger
import glob
import re


stanford_classifier = "/Users/zhengruixing/Desktop/stanford-ner-2020-11-17/classifiers/english.all.3class.distsim.crf.ser.gz"
stanford_ner_path = "/Users/zhengruixing/Desktop/stanford-ner-2020-11-17/stanford-ner.jar"


ner_tagger = StanfordNERTagger(stanford_classifier, stanford_ner_path, encoding='utf-8')

liste_entitesnom = []
liste_mots = []


for path_fichier in glob.glob("/Users/zhengruixing/Desktop/Corpus/*.txt"):
    with open(path_fichier, "r", encoding="utf-8") as f:
        texte = f.read().strip()


    words = nltk.word_tokenize(texte)
    ner_results = ner_tagger.tag(words)


    for word, tag in ner_results:
        if tag != "O":
            liste_entitesnom.append({"mot": word, "type": tag})
        else:
            liste_mots.append(word)
    """
    words_chunks = [words[i:i+512] for i in range(0, len(words), 512)]

    for chunk in words_chunks:
        ner_results = ner_tagger.tag(chunk)

        for word, tag in ner_results:
            if tag != "O":
                liste_entitesnom.append({"mot": word, "type": tag})
            else:
                liste_mots.append(word)
    """



print(f"Entités   : {len(liste_entitesnom)}")
print(f"Candidats : {len(liste_mots)}")
print(liste_entitesnom[:20])
print("-"*20)
print(list(liste_mots)[:20])
# Out:
# Entités   : 3788
# Candidats : 291375
# [{'mot': 'Texte', 'type': 'ORGANIZATION'}, {'mot': 'Vues', 'type': 'ORGANIZATION'}, {'mot': 'Calligrammes', 'type': 'ORGANIZATION'}, {'mot': '', 'type': 'ORGANIZATION'}, {'mot': 'Guillaume', 'type': 'ORGANIZATION'}, {'mot': 'Apollinaire', 'type': 'ORGANIZATION'}, {'mot': 'Guillaume', 'type': 'PERSON'}, {'mot': 'Lausanne', 'type': 'LOCATION'}, {'mot': 'Roger', 'type': 'PERSON'}, {'mot': 'France', 'type': 'LOCATION'}, {'mot': 'Il', 'type': 'PERSON'}, {'mot': 'GUILLAUME', 'type': 'PERSON'}, {'mot': 'APOLLINAIRE', 'type': 'PERSON'}, {'mot': 'Cordes', 'type': 'PERSON'}, {'mot': 'Cordes', 'type': 'PERSON'}, {'mot': 'Cordes', 'type': 'PERSON'}, {'mot': 'Cordes', 'type': 'PERSON'}, {'mot': 'Bigorneaux', 'type': 'LOCATION'}, {'mot': 'Lotte', 'type': 'LOCATION'}, {'mot': 'Puits', 'type': 'PERSON'}]
# --------------------
# ['Rappel', 'de', 'votre', 'demande', ':', 'Format', 'de', 'téléchargement', ':', ':', '1', 'à', '262', 'sur', '262', 'Nombre', 'de', 'pages', ':', '262']

# %%
import json

with open("/Users/zhengruixing/Desktop/Corpus/entitesnom_Standford.json", "w", encoding="utf-8") as f:
    json.dump({"EN": liste_entitesnom}, f, indent=4, ensure_ascii=False)
